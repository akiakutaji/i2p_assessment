# %% [markdown]
# # Assessment 2 Data Biography

# %%
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt

# %%
listings=pd.read_csv('2020-08-24-listings.csv.gz',compression='gzip',low_memory=False)

# %%
listings.shape
# Out:
# (74188, 74)

# %%
listings.describe()
# Out:
#                  id       host_id  host_listings_count  \
# count  7.418600e+04  7.418800e+04         74175.000000
# mean   2.524026e+07  9.403591e+07            22.460775
# std    1.292372e+07  9.804038e+07           115.784574
# min    1.155100e+04  1.000000e+00             0.000000
# 25%    1.504579e+07  1.578421e+07             1.000000
# 50%    2.576235e+07  4.911094e+07             1.000000
# 75%    3.697921e+07  1.529342e+08             4.000000
# max    4.509040e+07  3.639824e+08          1309.000000
#
#        neighbourhood_group_cleansed      latitude     longitude  accommodates  \
# count                      2.000000  74186.000000  74186.000000  74186.000000
# mean                     570.000000     51.508588     -0.128352      3.129755
# std                      784.888527      0.261351      0.095638      1.989834
# min                       15.000000      2.000000     -0.496250      1.000000
# ...

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74188 entries, 0 to 74187
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            74186 non-null  float64
#  1   listing_url                                   74187 non-null  object
#  2   scrape_id                                     74187 non-null  object
#  3   last_scraped                                  74187 non-null  object
#  4   name                                          74167 non-null  object
#  5   description                                   71329 non-null  object
#  6   neighborhood_overview                         47208 non-null  object
#  7   picture_url                                   74188 non-null  object
#  8   host_id                                       74188 non-null  float64
# ...

# %%
listings.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'description',
#        'neighborhood_overview', 'picture_url', 'host_id', 'host_url',
#        'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
# ...

# %%
msno.matrix(listings,labels=True)
plt.savefig('Matrix.png', dpi=300, bbox_inches='tight')

# %%
listings.isnull().sum(axis=0).sort_values(ascending=False)
# Out:
# license                         74188
# neighbourhood_group_cleansed    74186
# calendar_updated                74186
# host_response_rate              36409
# host_response_time              36407
#                                 ...
# scrape_id                           1
# listing_url                         1
# host_url                            0
# host_id                             0
# picture_url                         0
# Length: 73, dtype: int64

# %%
listings.isnull().sum(axis=0).sort_values(ascending=False).to_excel('test.xlsx')

# %%
listings.isnull().sum(axis=0).sum()
# Out:
# 644822

# %%
listings.isnull().sum(axis=0).plot.hist(bins=30)
plt.xlabel("Null values count")
plt.savefig('Frequency of null value.png',dpi=150)

# %%
listings.isnull().sum(axis=1).sort_values(ascending=False)
# Out:
# 29989    60
# 3558     60
# 8015     31
# 8052     31
# 8992     31
#          ..
# 19379     4
# 19374     4
# 19371     4
# 19367     4
# 20027     4
# Length: 74188, dtype: int64

# %%
listings.loc[[29989,3558]][['id','name','latitude','longitude','room_type','accommodates','price','availability_30','availability_365']]
# Out:
#                id                                           name  latitude  \
# 29989  21549106.0  Richmond Luxury, High ceilings & Free Parking       NaN
# 3558    3138549.0             Heart of City of London/Shoreditch       NaN
#
#        longitude room_type  accommodates price  availability_30  \
# 29989        NaN       NaN           NaN   NaN              NaN
# 3558         NaN       NaN           NaN   NaN              NaN
#
#        availability_365
# 29989               NaN
# 3558                NaN

# %%
listings[listings.id.isna()][['id','name','latitude','longitude','room_type','accommodates','price','availability_30','availability_365',]]
# Out:
#        id name  latitude  longitude room_type  accommodates price  \
# 3559  NaN    f       2.0        2.0        15           2.0     0
# 29990 NaN    f       2.0        2.0      1125           2.0    10
#
#        availability_30  availability_365
# 3559               9.0               9.0
# 29990             10.0              10.0

# %%
listings['room_type'].value_counts()
# Out:
# Entire home/apt    40853
# Private room       32163
# Shared room          592
# Hotel room           576
# 15                     1
# 1125                   1
# Name: room_type, dtype: int64

# %%
listings['property_type'].value_counts()
# Out:
# Entire apartment                 31459
# Private room in apartment        17146
# Private room in house            10757
# Entire house                      5317
# Private room in townhouse         1539
#                                  ...
# Shared room in tent                  1
# Lighthouse                           1
# Shared room in bus                   1
# Private room in parking space        1
# Yurt                                 1
# Name: property_type, Length: 93, dtype: int64

# %%
listings.price.sort_values(ascending=False)
# Out:
# 29990         10
# 3559           0
# 56234    $999.00
# 31079    $999.00
# 31904    $999.00
#           ...
# 68155      $0.00
# 60590      $0.00
# 66757      $0.00
# 3558         NaN
# 29989        NaN
# Name: price, Length: 74188, dtype: object

# %%
listings.loc[[3558,29989,3559,29990]][['id','name','latitude','longitude','room_type','accommodates','price','availability_30','availability_365']].to_excel('rows.xlsx')
